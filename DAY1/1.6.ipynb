# %%
import nltk

# %%
from nltk.stem.porter import *

# %%
p_stemmer = PorterStemmer()

# %%
words= {'run','runner','ran','running'}
print('Poerter stemmer')
for word in words:
  print(word +'------->'+ p_stemmer.stem(word))
# Out:
# Poerter stemmer
# running------->run
# runner------->runner
# ran------->ran
# run------->run

# %%
from nltk.stem.snowball import SnowballStemmer

# %%
s_stemmer = SnowballStemmer(language ='english')
print('Poerter2 stemmer')
for word in words:
  print(word +'------->'+ s_stemmer.stem(word))
# Out:
# Poerter2 stemmer
# running------->run
# runner------->runner
# ran------->ran
# run------->run

# %%
phrase ='I am meeting him tomorrow at the meeting'
for word in phrase.split():
  print( word +'---->'+p_stemmer.stem(word))
# Out:
# I---->i
# am---->am
# meeting---->meet
# him---->him
# tomorrow---->tomorrow
# at---->at
# the---->the
# meeting---->meet
