# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'already', 'take', 'them', 'latterly', 'each', 'once', 'seem', 'top', 'whole', 'neither', 'nothing', 'he', 'hundred', 'thereby', 'toward', 'throughout', 'who', 'whereupon', 'doing', 'how', 'has', 'she', 'never', 'then', 'before', 'eleven', 'became', 'name', 'all', 'across', 'ours', 'whereas', 'side', 'above', 'seems', 'the', 'somewhere', 'anyhow', 'more', 'just', 'whether', 'in', 'some', 'if', 'eight', 'could', 'its', 'every', 'yourself', 'put', 'themselves', 'whose', 'anything', 'someone', 'back', 'twelve', 'against', 'next', 'among', 'thereafter', 'further', 'four', 'last', 'as', 'be', 'off', "'ll", "'m", 'yourselves', 'n‘t', 'does', 'three', 'unless', 'you', 'below', 'him', 'part', 'own', 'together', 'somehow', 'again', 'anywhere', 'whenever', 'nor', 'that', 'meanwhile', 'amongst', 'seeming', 'thru', 'enough', 'into', 'with', 'did', 'whereafter', 'they', 'everything', 'show', "'d", 'bottom', 'ca', '’ve', 'my', 'less', '’m', '‘d', 'go', 'may', 'one', 'another', 'yet', 'up', '‘s', "n't", 'about', 'become', 'hence', 'make', 'nowhere', 'where', 'see', 'hereupon', 'when', 'anyone', 'elsewhere', 'beside', 'herein', 'which', '‘ve', 'under', 'after', 'at', 'out', 'were', 'to', 'hereafter', 'we', 'get', 'those', 'regarding', 'made', 'sixty', 'due', 'behind', 'from', 'same', 'hers', 'empty', 'either', 'various', '‘re', 'full', 'almost', 'here', 'myself', 'move', 'without', 'had', 'fifteen', 'otherwise', 'or', 'becoming', 'via', 'fifty', 'will', '‘ll', 'seemed', 'not', 'it', 'cannot', 'always', 'done', 'five', 'itself', 'well', 'several', 'i', 'down', 'such', 'over', 'others', 'by', 'least', 'latter', 'me', 'much', 'none', '’s', 'being', 'have', 'between', 'our', 'since', 'beforehand', 'wherein', 'was', 're', 'himself', 'using', 'former', 'towards', 'would', 'whatever', 'something', 'herself', 'perhaps', 'thus', 'until', 'per', 'front', 'so', 'nevertheless', 'been', 'am', 'but', 'this', 'both', 'hereby', 'mostly', 'therein', 'though', 'everywhere', 'why', 'ever', 'whoever', 'must', "'s", 'nobody', 'used', 'are', 'should', 'besides', 'of', 'than', 'namely', 'can', 'anyway', 'also', 'very', 'now', 'few', 'their', "'re", 'whither', 'sometimes', 'becomes', 'many', 'call', 'third', 'upon', 'forty', 'what', 'please', 'a', 'might', 'moreover', 'around', 'only', 'six', 'twenty', 'us', 'yours', 'there', 'afterwards', 'while', 'and', 'do', 'quite', 'an', 'first', '’re', 'mine', '’ll', 'through', 'alone', 'on', 'his', 'because', 'for', 'her', 'except', 'n’t', 'although', 'these', '’d', 'serious', 'formerly', 'noone', 'say', 'thereupon', 'no', 'two', 'still', 'whence', 'within', 'everyone', '‘m', 'beyond', 'wherever', 'however', 'rather', 'whereby', 'ten', 'indeed', 'even', 'else', 'thence', 'is', 'onto', 'nine', 'too', 'often', 'any', "'ve", 'during', 'really', 'along', 'keep', 'therefore', 'sometime', 'your', 'most', 'give', 'ourselves', 'whom', 'other', 'amount'}

# %%
nlp.vocab['them'].is_stop
# Out:
# True

# %%
nlp.vocab['mystery'].is_stop
# Out:
# False

# %%
nlp.Defaults.stop_words.add('btw')
nlp.vocab['btw'].is_stop
len(nlp.Defaults.stop_words)
# Out:
# 327
