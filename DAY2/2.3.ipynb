# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
from spacy.matcher import Matcher
matcher = Matcher(nlp.vocab)

# %%
pattern1 =[{'LOWER':'solarpower'}]
pattern2 =[{'LOWER':'solar'},{'LOWER':'power'}]
pattern3 = [{'LOWER':'solar'},{'IS_PUNCT':True},{'LOWER':'power'}]

# %%
matcher.add('SolarPower',[pattern1,pattern2,pattern3])

# %%
doc=nlp(u'The Solar Power industry continuous to grow as demand \
for solarpower increase.solar-power cars are gaining popularity.')

# %%
found_matches = matcher(doc)
print(found_matches)
# Out:
# [(8656102463236116519, 1, 3), (8656102463236116519, 10, 11)]

# %%
for match_id, start, end in found_matches:
    string_id = nlp.vocab.strings[match_id]
    span = doc[start:end]
    print(match_id, string_id, start, end, span.text)
# Out:
# 8656102463236116519 SolarPower 1 3 Solar Power
# 8656102463236116519 SolarPower 10 11 solarpower

# %%
pwd
# Out:
# '/content'

# %%
from spacy.matcher import PhraseMatcher
matcher = PhraseMatcher(nlp.vocab)

# %%
with open (r'/reaganomics.txt', encoding='cp1252')as f:
  doc3 = nlp(f.read())

# %%
phrase_list = ['voodon economics','supply-side economics','trickle-down economics','free-market economics']
phrase_patterns = [nlp(text) for text in phrase_list]
matcher.add('VoodonEconomics', None,*phrase_patterns)
matchers= matcher(doc3)

# %%
matchers
# Out:
# [(2055734533305922416, 41, 45),
#  (2055734533305922416, 49, 53),
#  (2055734533305922416, 61, 65),
#  (2055734533305922416, 673, 677),
#  (2055734533305922416, 2987, 2991)]

# %%
doc3[:70]
# Out:
# REAGANOMICS
# https://en.wikipedia.org/wiki/Reaganomics
#
# Reaganomics (a portmanteau of [Ronald] Reagan and economics attributed to Paul Harvey)[1] refers to the economic policies promoted by U.S. President Ronald Reagan during the 1980s. These policies are commonly associated with supply-side economics, referred to as trickle-down economics or voodoo economics by political opponents, and free-market economics by political advocates.

# %%
doc3[665:675]
# Out:
# same time he attracted a following from the supply-

# %%
doc3[2975:2995]
# Out:
# ) lawsuits against institutions.[66] His policies became widely known as "trickle-down economics", due to

# %%
sents = [sent for sent in doc3.sents]
print(sents[0].start, sents[0].end)
# Out:
# 0 35

# %%
for sent in sents:
  if matchers[4][1] < sent.end:
    print(sent)
    break
# Out:
# His policies became widely known as "trickle-down economics", due to the significant cuts in the upper tax brackets, as that extra money for the wealthy could trickle along to low-income groups.[67]
#
# Federal income tax and payroll tax levels
#
# During the Reagan administration, fiscal year federal receipts grew from $599 billion to $991 billion (an increase of 65%) while fiscal year federal outlays grew from $678 billion to $1144 billion (an increase of 69%).[68][69]
