#        -0.4220463 ,  0.11029564, -0.614316  ,  0.39858642, -0.400296  ,
#        -0.27928865,  0.03041822, -0.28582293,  0.10202064, -0.11624302,
#         0.3889851 ,  0.75077003, -0.31747788, -0.07403845,  0.11649389,
#         0.10007934,  0.34222552,  0.59273833,  0.44912046, -0.33345807,
#        -0.3255919 ], dtype=float32)

# %%
tokens = nlp(u'lion cat pet')
tokens
# Out:
# lion cat pet

# %%
for token1 in tokens:
  for token2 in tokens:
    print(token1.text,token2.text,token1.similarity(token2))
# Out:
# lion lion 1.0
# lion cat 0.7044516205787659
# lion pet 0.3186751902103424
# cat lion 0.7044516205787659
# cat cat 1.0
# cat pet 0.36159902811050415
# pet lion 0.3186751902103424
# pet cat 0.36159902811050415
# pet pet 1.0
# /tmp/ipython-input-914047137.py:3: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Token.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   print(token1.text,token2.text,token1.similarity(token2))

# %%
nlp(u'lion').similarity(nlp(u'dandelion'))
# Out:
# /tmp/ipython-input-1276038593.py:1: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   nlp(u'lion').similarity(nlp(u'dandelion'))
# 0.7058143615722656

# %%
tokens = nlp(u' love like here')
for token1 in tokens:
  for token2 in tokens:
    print(token1.text,token2.text,token1.similarity(token2))
# Out:
#     1.0
#   love 0.04361095651984215
#   like -0.027747035026550293
#   here 0.03770992532372475
# love   0.04361095651984215
# love love 1.0
# love like 0.00011523594002937898
# love here 0.03018038347363472
# like   -0.027747035026550293
# like love 0.00011523594002937898
# like like 1.0
# like here 0.18770897388458252
# here   0.03770992532372475
# here love 0.03018038347363472
# here like 0.18770897388458252
# here here 1.0
# /tmp/ipython-input-2715115423.py:4: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Token.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   print(token1.text,token2.text,token1.similarity(token2))

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

# %%
a = 'This is a good movie'
sid.polarity_scores(a)
# Out:
# {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}

# %%
a= ' This was the best, most awesome movie EVER MADE!!!'
sid.polarity_scores(a)
# Out:
# {'neg': 0.0, 'neu': 0.425, 'pos': 0.575, 'compound': 0.8877}

# %%
a='This was the worst film to ever disgrace the screen. '
sid.polarity_scores(a)
# Out:
# {'neg': 0.477, 'neu': 0.523, 'pos': 0.0, 'compound': -0.8074}

# %%
import numpy as np
import pandas as pd
df = pd.read_csv(r'/content/amazonreviews.tsv', sep='\t')
df.head()
# Out:
#   label                                             review
# 0   pos  Stuning even for the non-gamer: This sound tra...
# 1   pos  The best soundtrack ever to anything.: I'm rea...
# 2   pos  Amazing!: This soundtrack is my favorite music...
# 3   pos  Excellent Soundtrack: I truly like this soundt...
# 4   pos  Remember, Pull Your Jaw Off The Floor After He...

# %%
df['label'].value_counts()
# Out:
# label
# neg    5097
# pos    4903
# Name: count, dtype: int64

# %%
df.dropna(inplace=True)

# %%
df['label'].value_counts()
# Out:
# label
# neg    5097
# pos    4903
# Name: count, dtype: int64

# %%
blanks = []
for i,lb,rv in df.itertuples():
  if type(rv) == str:
    if rv.isspace():
      blanks.append(i)
df.drop(blanks, inplace = True)
df['label'].value_counts()
# Out:
# label
# neg    5097
# pos    4903
# Name: count, dtype: int64

# %%
sid.polarity_scores(df.loc[0]['review'])
df.loc[0]['label']
# Out:
# 'pos'

# %%
df['scores'] = df['review'].apply(lambda review: sid.polarity_scores(review))
df.head()
# Out:
#   label                                             review  \
# 0   pos  Stuning even for the non-gamer: This sound tra...
# 1   pos  The best soundtrack ever to anything.: I'm rea...
# 2   pos  Amazing!: This soundtrack is my favorite music...
# 3   pos  Excellent Soundtrack: I truly like this soundt...
# 4   pos  Remember, Pull Your Jaw Off The Floor After He...
#
#                                               scores
# 0  {'neg': 0.088, 'neu': 0.669, 'pos': 0.243, 'co...
# 1  {'neg': 0.018, 'neu': 0.837, 'pos': 0.145, 'co...
# 2  {'neg': 0.04, 'neu': 0.692, 'pos': 0.268, 'com...
# 3  {'neg': 0.09, 'neu': 0.615, 'pos': 0.295, 'com...
# 4  {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...

# %%
df['compound'] = df['scores'].apply(lambda score_dict: score_dict['compound'])
df.head()
# Out:
#   label                                             review  \
# 0   pos  Stuning even for the non-gamer: This sound tra...
# 1   pos  The best soundtrack ever to anything.: I'm rea...
# 2   pos  Amazing!: This soundtrack is my favorite music...
# 3   pos  Excellent Soundtrack: I truly like this soundt...
# 4   pos  Remember, Pull Your Jaw Off The Floor After He...
#
#                                               scores  compound
# 0  {'neg': 0.088, 'neu': 0.669, 'pos': 0.243, 'co...    0.9454
# 1  {'neg': 0.018, 'neu': 0.837, 'pos': 0.145, 'co...    0.8957
# 2  {'neg': 0.04, 'neu': 0.692, 'pos': 0.268, 'com...    0.9858
# 3  {'neg': 0.09, 'neu': 0.615, 'pos': 0.295, 'com...    0.9814
# 4  {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...    0.9781

# %%
sid.polarity_scores(df.loc[0]['review'])
df.loc[0]['scores']
# Out:
# {'neg': 0.088, 'neu': 0.669, 'pos': 0.243, 'compound': 0.9454}

# %%
df['comp_score'] = df['compound'].apply(lambda c: 'pos' if c >=0 else 'neg')
df.head()
# Out:
#   label                                             review  \
# 0   pos  Stuning even for the non-gamer: This sound tra...
# 1   pos  The best soundtrack ever to anything.: I'm rea...
# 2   pos  Amazing!: This soundtrack is my favorite music...
# 3   pos  Excellent Soundtrack: I truly like this soundt...
# 4   pos  Remember, Pull Your Jaw Off The Floor After He...
#
#                                               scores  compound comp_score
# 0  {'neg': 0.088, 'neu': 0.669, 'pos': 0.243, 'co...    0.9454        pos
# 1  {'neg': 0.018, 'neu': 0.837, 'pos': 0.145, 'co...    0.8957        pos
# 2  {'neg': 0.04, 'neu': 0.692, 'pos': 0.268, 'com...    0.9858        pos
# 3  {'neg': 0.09, 'neu': 0.615, 'pos': 0.295, 'com...    0.9814        pos
# 4  {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...    0.9781        pos

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
accuracy_score(df['label'],df['comp_score'])
# Out:
# 0.7098

# %%
print(confusion_matrix(df['label'],df['comp_score']))
# Out:
# [[2630 2467]
#  [ 435 4468]]

# %%
print(classification_report(df['label'],df['comp_score']))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.86      0.52      0.64      5097
#          pos       0.64      0.91      0.75      4903
#
#     accuracy                           0.71     10000
#    macro avg       0.75      0.71      0.70     10000
# weighted avg       0.75      0.71      0.70     10000

# %%
--
