# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('/content/drive/MyDrive/Advanced AI/dog_backpack.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=934x1401>

# %%
import cv2

# %%
img = cv2.imread('/content/drive/MyDrive/Advanced AI/dog_backpack.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()

# %%
cv2.circle(img_rgb, center=(420,575), radius=220,color=(255,0,0), thickness=20)
plt.imshow(img_rgb)
plt.show()
